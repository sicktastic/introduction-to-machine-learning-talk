# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
a = cv2.imread('5.png', 0)
plt.imshow(a, cmap='gray', interpolation='bicubic')

# %%
print(a.shape)
# Out:
# (28, 28)

# %%
print(a)
# Out:
# [[255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#   255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#   255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255 255
#   255 255 255 255 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 250 110  79 221 255 255 255 255
#   255 243  92 168 255 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 252 149   0   0 124 208 121  85  94
#    96  66   0  17 180 255 255 255 255 255]
#  [255 255 255 255 255 255 255 255 255 255 110   0   0  20  46   0   0   0
#     0   0   0   0  21 221 255 255 255 255]
#  [255 255 255 255 255 255 255 255 225 138  51   0   1   0   0   0   0   0
#     0   0  11  58 127 217 255 255 255 255]
#  [255 255 255 255 255 255 255 255 241  57   0   0   0   0   0   0   0  44
#    91 147 173 225 255 255 255 255 255 255]
# ...
